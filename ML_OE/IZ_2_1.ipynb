# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
# Считываем содержимое файла в переменную data:
schet = np.genfromtxt('/Users/muzafarov/Desktop/MyEducation/ML_OE/X_reduced_428.csv', delimiter=';')
weight = np.genfromtxt('/Users/muzafarov/Desktop/MyEducation/ML_OE/X_loadings_428.csv', delimiter=';')

print(np.shape(schet))
print(np.shape(weight))
# Out:
# (100, 10)
# (100, 10)

# %%
weight = np.transpose(weight)
print(np.shape(weight))
# Out:
# (10, 100)

# %%
result = np.matmul(schet,weight)

# %%
plt.imshow(result)
plt.show()
