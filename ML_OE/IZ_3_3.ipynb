# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/Users/muzafarov/Desktop/MyEducation/ML_OE/fish_train.csv')
df.head(5)
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Roach   150.0     20.4     22.0     24.7   5.8045  3.7544
# 1   Perch   250.0     25.4     27.5     28.9   7.2828  4.5662
# 2   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 3   Bream   925.0     36.2     39.5     45.3  18.7542  6.7497
# 4   Perch   110.0     19.0     21.0     22.5   5.6925  3.5550

# %%
train, test = train_test_split(df, test_size=0.2, random_state=23, stratify=df['Species'])
new_df = train

# %%
Y_train = train.pop('Weight')
Y_test = test.pop('Weight')

# %%
spec_train = train.pop('Species')
spec_test = test.pop('Species')
train.head(5)
# Out:
#     Length1  Length2  Length3   Height   Width
# 84     11.4     12.0     13.2   2.2044  1.1484
# 32     24.0     26.0     29.2   8.8768  4.4968
# 82     56.0     60.0     64.0   9.6000  6.1440
# 3      36.2     39.5     45.3  18.7542  6.7497
# 24     28.7     31.0     36.2  14.3714  4.8146

# %%
regressor = LinearRegression()
rabota = regressor.fit(train, Y_train)

# %%
Y_pred = regressor.predict(test)

# %%
sravnenie = pd.DataFrame({'Предсказанные': Y_pred, 'Действительные': Y_test})
sravnenie.head(10)
# Out:
#      Предсказанные  Действительные
# 31      685.061467           800.0
# 62      621.284657           456.0
# 43      219.195205           160.0
# 26      542.001459           500.0
# 80      424.160555           300.0
# 27      900.397667          1100.0
# 64      626.595080           514.0
# 114     387.614256           273.0
# 57      208.771587           150.0
# 30      637.430263           650.0

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.8885408749541968

# %%
train_reserv = train
train = train.drop(['Height', 'Width'], axis=1)

pca = PCA(n_components=1, svd_solver='full')
data_transformed = pca.fit_transform(train) # перевод в базис главных компонент
z_val_train = data_transformed
z_val_train
# Out:
# array([[-2.83888965e+01],
#        [-3.69350201e+00],
#        [ 5.45162318e+01],
#        [ 2.05627148e+01],
#        [ 6.02998760e+00],
#        [ 1.92429082e+00],
#        [-2.61473379e+00],
#        [ 2.84974788e+01],
#        [ 1.43255006e+01],
#        [ 1.10562976e+01],
#        [ 1.45616637e+01],
#        [ 6.11644725e+00],
#        [-3.29093369e+00],
#        [-1.07050690e+01],
#        [-9.02118074e+00],
#        [-1.71669659e+00],
#        [-1.34928365e+01],
#        [ 1.72170515e+01],
#        [-3.52693635e+01],
#        [-3.36674746e-02],
#        [-1.53233814e+01],
#        [-1.30811767e+01],
#        [-1.77003726e+01],
#        [ 1.95964252e+01],
#        [ 9.51324060e+00],
#        [-1.43488595e+01],
#        [-3.02417738e+01],
#        [-2.26894396e+00],
#        [ 1.37591532e+01],
#        [ 1.63525769e+01],
#        [-2.94836843e+01],
#        [ 2.30627751e+01],
#        [-3.61485405e+00],
#        [-1.16626878e+01],
#        [-2.22249010e+01],
#        [-1.16626878e+01],
#        [ 3.33735056e+00],
#        [-7.80573074e+00],
#        [-2.28260550e+00],
#        [ 1.10418013e+01],
#        [ 7.59839925e+00],
#        [ 4.18556187e+00],
#        [ 1.30383130e+01],
#        [ 5.75070755e+00],
#        [-1.97031726e+01],
#        [ 1.80195620e+01],
#        [-1.33916369e+01],
#        [-2.26894396e+00],
#        [-1.33916369e+01],
#        [-2.26894396e+00],
#        [-4.21737234e+00],
#        [ 5.86945009e+00],
#        [ 9.38931247e+00],
#        [-1.40446938e+00],
#        [-9.99268032e+00],
#        [ 1.28190530e+01],
#        [-2.45215017e+01],
#        [ 2.24379245e+01],
#        [-5.17243166e+00],
#        [-1.16850201e+01],
#        [ 2.03230909e+01],
#        [-9.93373860e+00],
#        [-2.48657681e+01],
#        [ 1.80111104e+01],
#        [-3.97039957e+00],
#        [ 2.44368430e+01],
#        [-3.22630003e+01],
#        [ 3.01475608e+01],
#        [-2.36700244e+01],
#        [ 1.80195620e+01],
#        [-2.36470522e+01],
#        [-1.46946493e+01],
#        [-2.97185433e+01],
#        [ 1.03493381e+01],
#        [ 1.93654721e+01],
#        [ 1.27120280e+01],
#        [ 3.37012294e+01],
#        [ 2.12384456e+00],
#        [-1.31301435e+01],
#        [ 1.95429127e+01],
#        [-3.09907718e+01],
#        [ 6.60459171e+00],
#        [-2.78127934e+01],
#        [ 4.55975314e+00],
#        [-1.16626878e+01],
#        [ 1.60093888e+01],
#        [-2.28196564e+00],
#        [ 1.86028125e+01],
#        [-1.16626878e+01],
#        [ 1.51423125e+01],
#        [ 2.49691649e+01],
#        [ 1.45532121e+01],
#        [-1.04524233e+01],
#        [-1.33916369e+01],
#        [ 2.34113615e+00]])

# %%
train_reserv= train_reserv.drop(['Length1', 'Length2', 'Length3'], axis=1)
train_reserv['Lengths'] = z_val_train

# %%
train_reserv.head(4)
# Out:
#      Height   Width    Lengths
# 84   2.2044  1.1484 -28.388897
# 32   8.8768  4.4968  -3.693502
# 82   9.6000  6.1440  54.516232
# 3   18.7542  6.7497  20.562715

# %%
test_reserv = test
test = test.drop(['Height', 'Width'], axis=1)

# pca = PCA(n_components=1, svd_solver='full')
data_transformed = pca.transform(test) # перевод в базис главных компонент
z_val_test = data_transformed
z_val_test
# Out:
# array([[ 13.91298171],
#        [ 24.44266843],
#        [ -9.85749751],
#        [  6.65505747],
#        [ -3.81743014],
#        [ 24.78327268],
#        [  6.66353343],
#        [ -5.54637929],
#        [-10.79821317],
#        [ 10.24533548],
#        [ -7.15140032],
#        [-18.65735157],
#        [ 40.11524443],
#        [ -5.55394736],
#        [ 47.414543  ],
#        [ -7.10545588],
#        [ 18.54084846],
#        [ -9.06926402],
#        [ 12.70357642],
#        [ 25.43369726],
#        [-28.61920977],
#        [-28.61920977],
#        [-10.89941272],
#        [  7.71387582]])

# %%
test_reserv= test_reserv.drop(['Length1', 'Length2', 'Length3'], axis=1)
test_reserv['Lengths'] = z_val_test

# %%
regressor = LinearRegression()
rabota = regressor.fit(train_reserv, Y_train)
Y_pred = regressor.predict(test_reserv)

# %%
sravnenie = pd.DataFrame({'Предсказанные': Y_pred, 'Действительные': Y_test})
sravnenie.head(10)
# Out:
#      Предсказанные  Действительные
# 31      693.917037           800.0
# 62      592.574769           456.0
# 43      222.137746           160.0
# 26      512.447367           500.0
# 80      372.791763           300.0
# 27      860.279437          1100.0
# 64      567.058260           514.0
# 114     346.979470           273.0
# 57      207.308445           150.0
# 30      641.740491           650.0

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.8925481416058357

# %%
train_reserv['Height'] = train_reserv['Height']**3
train_reserv['Width'] = train_reserv['Width']**3
train_reserv['Lengths'] = train_reserv['Lengths']**3

test_reserv['Height'] = test_reserv['Height']**3
test_reserv['Width'] = test_reserv['Width']**3
test_reserv['Lengths'] = test_reserv['Lengths']**3
test_reserv
# Out:
#           Height       Width        Lengths
# 31   1626.877698  284.059829    2693.150620
# 62    385.828352   80.761617   14603.126579
# 43    262.144000   54.872000    -957.855569
# 26   2604.830992   83.338924     294.751098
# 80   1469.102828   75.901885     -55.630542
# 27   1958.990236  407.940668   15222.148898
# 64   1009.027027  217.949838     295.878728
# 114  1363.200233   71.163818    -170.619513
# 57    313.323545   47.595355   -1259.086858
# 30   3032.129192  187.896219    1075.421097
# 66    427.706666   56.411033    -365.740680
# 91    142.432927   36.647301   -6494.563778
# 35    711.213252  235.022188   64554.768543
# 5     282.429536   76.171104    -171.318900
# 93   1220.343483  340.785085  106594.477946
# 109   305.283438   72.292833    -358.736727
# 20   5914.029617  249.095649    6373.658832
# 71    247.082047   51.686703    -745.961022
# 92   4283.494243  174.583151    2050.114008
# 37   2002.281725  539.750799   16452.370930
# 36     10.851106    2.115885  -23440.826144
# 13     10.851106    1.584834  -23440.826144
# 89    291.948845   44.655750   -1294.819688
# 73   2693.103168  130.539883     459.005542

# %%
regressor.fit(train_reserv, Y_train)
Y_pred = regressor.predict(test_reserv)
r2_score(Y_test, Y_pred)
# Out:
# 0.9452890309259326

# %%
is_drop_first = False

last_train = train_reserv
last_train['Species'] = spec_train
last_train = pd.get_dummies (last_train, columns=['Species'], drop_first=is_drop_first)

last_test = test_reserv
last_test['Species'] = spec_test
last_test = pd.get_dummies (last_test, columns=['Species'], drop_first=is_drop_first)



regressor.fit(last_train, Y_train)
Y_pred = regressor.predict(last_test)
r2_score(Y_test, Y_pred)
# Out:
# 0.9525713724639515
