# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Сначала создали таблицу с данными из тестового задания в нормально читаемом формате csv и подгружаем ее для дальнейшей работы

# %%
df = pd.read_csv('Data_clients.csv')
df = df.drop(columns='client_id')
df
# Out:
#    first_name   last_name gender  age             city rented_equipment  \
# 0        Иван      Петров      M   35           Moscow            Drill
# 1       Мария    Сидорова      F   28              SPb           Ladder
# 2     Алексей       Орлов      M   42            Kazan              Saw
# 3       Ольга    Смирнова      F   25           Moscow           Sander
# 4      Сергей      Егоров      M   37           Rostov            Drill
# 5        Юлия    Соколова      F   29              SPb       Perforator
# 6      Андрей    Кузнецов      M   36    Yekaterinburg      Jack Hammer
# 7     Наталья     Козлова      F   41      Novosibirsk      Tile Cutter
# 8        Пётр      Волков      M   38           Moscow        Spray Gun
# 9       Лидия     Фролова      F   32           Rostov         Nail Gun
# 10  Александр     Кузьмин      M   44  Nizhny Novgorod    Paint Sprayer
# 11      Елена   Соловьева      F   37            Kazan      Tile Cutter
# 12      Антон     Королев      M   29           Moscow         Nail Gun
# 13       Анна      Орлова      F   26              SPb      Jack Hammer
# 14      Игорь    Савельев      M   41           Rostov    Paint Sprayer
# 15       Юлия     Павлова      F   33    Yekaterinburg            Drill
# 16      Роман     Соколов      M   30           Moscow              Saw
# 17      Олеся    Кузьмина      F   28      Krasnoyarsk           Ladder
# 18     Максим  Виноградов      M   36      Novosibirsk      Wall Sander
# 19    Валерия    Семёнова      F   29             Perm       Perforator
# 20      Фёдор     Смирнов      M   42              Ufa      Tile Cutter
# 21     Любовь    Кузьмина      F   38         Voronezh        Spray Gun
# 22     Даниил       Орлов      M   25           Moscow    Paint Sprayer
# 23     Карина     Ефимова      F   19             Omsk      Jack Hammer
# 24     Виктор     Ковалёв      M   29           Rostov              Saw
# 25  Анастасия    Суворова      F   26           Samara            Drill
# 26     Никита      Волков      M   34           Moscow           Ladder
# 27      Алина    Кулагина      F   24   St. Petersburg         Nail Gun
# 28      Денис     Соболев      M   32      Novosibirsk      Wall Sander
# 29      Алёна    Широкова      F   27    Yekaterinburg       Perforator
# 30  Анастасия    Морозова      F   23             Perm      Wall Sander
#
#    rental_period rental_start_date rental_end_date  late_return  registration  \
# 0         5 days        01/01/2023      01/05/2023            0             2
# 1         3 days        03/01/2023      01/06/2023            1             1
# 2         7 days        02/02/2023      02/09/2023            0             0
# 3         2 days        05/02/2023      02/12/2023            1             2
# 4         4 days        09/02/2023      02/13/2023            0             1
# 5         4 days        11/02/2023      02/15/2023            1             0
# 6         6 days        10/02/2023      02/16/2023            0             1
# 7         3 days        15/02/2023      02/18/2023            0             0
# 8          1 day        17/02/2023      02/18/2023            1             2
# 9         5 days        20/02/2023      02/25/2023            0             1
# 10        4 days        22/02/2023      02/26/2023            0             1
# 11        5 days        25/02/2023      03/02/2023            1             0
# 12        2 days        28/02/2023      03/02/2023            0             2
# 13        6 days        02/03/2023      03/09/2023            1             1
# 14        3 days        04/03/2023      03/07/2023            0             1
# 15         1 day        09/03/2023      03/10/2023            1             1
# 16        7 days        06/03/2023      03/13/2023            0             2
# 17        4 days        11/03/2023      03/15/2023            0             0
# 18        5 days        10/03/2023      03/15/2023            1             0
# 19        3 days        16/03/2023      03/19/2023            0             1
# 20        2 days        14/03/2023      03/16/2023            1             1
# 21        6 days        20/03/2023      03/26/2023            0             1
# 22        5 days        18/03/2023      03/23/2023            1             2
# 23        4 days        22/03/2023      03/26/2023            0             0
# 24        3 days        21/03/2023      03/24/2023            0             1
# 25        7 days        25/03/2023      04/01/2023            1             1
# 26        2 days        27/03/2023      03/29/2023            0             2
# 27        5 days        01/04/2023      04/06/2023            0             1
# 28        4 days        30/03/2023      04/03/2023            1             0
# 29        6 days        03/04/2023      04/09/2023            0             1
# 30        2 days        17/03/2023      03/19/2023            0             0
#
#     debt_history
# 0              0
# 1              3
# 2              1
# 3              4
# 4              2
# 5              0
# 6              1
# 7              0
# 8              4
# 9              3
# 10             2
# 11             1
# 12             0
# 13             3
# 14             0
# 15             4
# 16             2
# 17             1
# 18             3
# 19             0
# 20             4
# 21             1
# 22             2
# 23             0
# 24             0
# 25             3
# 26             1
# 27             0
# 28             2
# 29             0
# 30             0

# %% [markdown]
# ## Функция для преобразования строки в количество дней

# %%
import re
# Функция для преобразования строки в количество дней
def extract_days(rental_period):
    match = re.search(r'\d+', rental_period)
    if match:
        return int(match.group())
    else:
        return None

# %% [markdown]
# ## Приводим в целочисленный вид столбец с количеством дней аренды

# %%
df['rental_period'] = df['rental_period'].apply(extract_days)
df.head(5)
# Out:
#   first_name last_name gender  age    city rented_equipment  rental_period  \
# 0       Иван    Петров      M   35  Moscow            Drill              5
# 1      Мария  Сидорова      F   28     SPb           Ladder              3
# 2    Алексей     Орлов      M   42   Kazan              Saw              7
# 3      Ольга  Смирнова      F   25  Moscow           Sander              2
# 4     Сергей    Егоров      M   37  Rostov            Drill              4
#
#   rental_start_date rental_end_date  late_return  registration  debt_history
# 0        01/01/2023      01/05/2023            0             2             0
# 1        03/01/2023      01/06/2023            1             1             3
# 2        02/02/2023      02/09/2023            0             0             1
# 3        05/02/2023      02/12/2023            1             2             4
# 4        09/02/2023      02/13/2023            0             1             2

# %%
df['city'].value_counts()
# Out:
# city
# Moscow             7
# Rostov             4
# SPb                3
# Yekaterinburg      3
# Novosibirsk        3
# Kazan              2
# Perm               2
# Nizhny Novgorod    1
# Krasnoyarsk        1
# Ufa                1
# Voronezh           1
# Omsk               1
# Samara             1
# St. Petersburg     1
# Name: count, dtype: int64

# %% [markdown]
# ## При анализе столбца city увидел, что есть строка St. Petersburg и SPb, а это один и тот же город. Просизвожу замену

# %%
# Заменяем 'St. Petersburg' на 'SPb'
df['city'] = df['city'].replace('St. Petersburg', 'SPb')
df.head(5)
# Out:
#   first_name last_name gender  age    city rented_equipment  rental_period  \
# 0       Иван    Петров      M   35  Moscow            Drill              5
# 1      Мария  Сидорова      F   28     SPb           Ladder              3
# 2    Алексей     Орлов      M   42   Kazan              Saw              7
# 3      Ольга  Смирнова      F   25  Moscow           Sander              2
# 4     Сергей    Егоров      M   37  Rostov            Drill              4
#
#   rental_start_date rental_end_date  late_return  registration  debt_history
# 0        01/01/2023      01/05/2023            0             2             0
# 1        03/01/2023      01/06/2023            1             1             3
# 2        02/02/2023      02/09/2023            0             0             1
# 3        05/02/2023      02/12/2023            1             2             4
# 4        09/02/2023      02/13/2023            0             1             2

# %% [markdown]
# ## Преобразуем календарные данные и создаем новый столбец по длительности аренды

# %%
# Преобразуем столбцы 'rental_start_date' и 'rental_end_date' в объекты datetime
df['rental_start_date'] = pd.to_datetime(df['rental_start_date'], dayfirst=True, errors='coerce')
df['rental_end_date'] = pd.to_datetime(df['rental_end_date'], errors='coerce')

# Создаем новый признак 'rental_duration' - продолжительность аренды
df['rental_duration'] = (df['rental_end_date'] - df['rental_start_date']).dt.days

df.head(5)
# Out:
#   first_name last_name gender  age    city rented_equipment  rental_period  \
# 0       Иван    Петров      M   35  Moscow            Drill              5
# 1      Мария  Сидорова      F   28     SPb           Ladder              3
# 2    Алексей     Орлов      M   42   Kazan              Saw              7
# 3      Ольга  Смирнова      F   25  Moscow           Sander              2
# 4     Сергей    Егоров      M   37  Rostov            Drill              4
#
#   rental_start_date rental_end_date  late_return  registration  debt_history  \
# 0        2023-01-01      2023-01-05            0             2             0
# 1        2023-01-03      2023-01-06            1             1             3
# 2        2023-02-02      2023-02-09            0             0             1
# 3        2023-02-05      2023-02-12            1             2             4
# 4        2023-02-09      2023-02-13            0             1             2
#
#    rental_duration
# 0                4
# 1                3
# 2                7
# 3                7
# 4                4

# %% [markdown]
# ## Удаляем ненужные столбцы и кодируем пол

# %%
# Удаляем столбцы 'rental_start_date', 'rental_end_date','first_name', 'last_name'
df = df.drop(columns={'rental_start_date','rental_end_date','first_name', 'last_name'})

# Заменяем мужской и женский пол на цифры 1 и 0.
df['gender'] = df['gender'].map({'M': 0, 'F': 1})

df.head(5)
# Out:
#    gender  age    city rented_equipment  rental_period  late_return  \
# 0       0   35  Moscow            Drill              5            0
# 1       1   28     SPb           Ladder              3            1
# 2       0   42   Kazan              Saw              7            0
# 3       1   25  Moscow           Sander              2            1
# 4       0   37  Rostov            Drill              4            0
#
#    registration  debt_history  rental_duration
# 0             2             0                4
# 1             1             3                3
# 2             0             1                7
# 3             2             4                7
# 4             1             2                4

# %% [markdown]
# ## Кодируем текстовые столбцы

# %%
df = pd.get_dummies(df, columns=['city', 'rented_equipment'], prefix=['city', 'equipment'])

df.head(5)
# Out:
#    gender  age  rental_period  late_return  registration  debt_history  \
# 0       0   35              5            0             2             0
# 1       1   28              3            1             1             3
# 2       0   42              7            0             0             1
# 3       1   25              2            1             2             4
# 4       0   37              4            0             1             2
#
#    rental_duration  city_Kazan  city_Krasnoyarsk  city_Moscow  ...  \
# 0                4       False             False         True  ...
# 1                3       False             False        False  ...
# 2                7        True             False        False  ...
# 3                7       False             False         True  ...
# 4                4       False             False        False  ...
#
#    equipment_Jack Hammer  equipment_Ladder  equipment_Nail Gun  \
# 0                  False             False               False
# 1                  False              True               False
# 2                  False             False               False
# 3                  False             False               False
# 4                  False             False               False
#
#    equipment_Paint Sprayer  equipment_Perforator  equipment_Sander  \
# 0                    False                 False             False
# 1                    False                 False             False
# 2                    False                 False             False
# 3                    False                 False              True
# 4                    False                 False             False
#
#    equipment_Saw  equipment_Spray Gun  equipment_Tile Cutter  \
# 0          False                False                  False
# 1          False                False                  False
# 2           True                False                  False
# 3          False                False                  False
# 4          False                False                  False
#
#    equipment_Wall Sander
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 31 columns]

# %%
X = df.drop(columns='late_return')
y = df['late_return']

# %% [markdown]
# ## Поделим данные на тренировочную и тестовую выборки, чтобы можно было оценить точность модели

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# Создание и обучение модели Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train)

# Предсказания на валидационном наборе
pred = model.predict(X_test)

# %%
f1_score(y_test, pred)
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix

print(classification_report(y_test, pred, digits=4))
tn, fp, fn, tp = confusion_matrix(pred, y_test).ravel()
print(f'true negative: {tn}')
print(f'false positive: {fp}')
print(f'false negative: {fn}')
print(f'true positive: {tp}')
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8889    1.0000    0.9412         8
#            1     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9091        11
#    macro avg     0.9444    0.8333    0.8706        11
# weighted avg     0.9192    0.9091    0.9027        11
#
# true negative: 8
# false positive: 1
# false negative: 0
# true positive: 2

# %% [markdown]
# ## Итог: точность предсказания модели 90%. Правильно определено 10 из 11. Только одна ошибка. Возможно при большем количестве данных можно было бы достичь больших результатов
