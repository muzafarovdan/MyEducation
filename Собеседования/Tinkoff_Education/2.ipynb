# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tests = int(input())

for test in range(tests):
    n = int(input())
    a = list(map(int, input().split()))
    if n == 1:
        print('Yes')
    else:
        if (n-1)*2 == sum(a):
            print('Yes')
        else:
            print('No')
# Out:
# Yes
# Yes
# No
# Yes
