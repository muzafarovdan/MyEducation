# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tests = int(input())

for test in range(tests):
    array = input()
    tinkoff = {'T': 1, 'I': 1, 'N': 1, 'K': 1, 'O': 1, 'F': 2}
    d = {}
    for i in array:
        if i in d:
            d[i] += 1
        else:
            d[i] = 1 
    if d == tinkoff:
        print('Yes')
    else:
        print('No')
# Out:
# Yes
# No
# No
# Yes
