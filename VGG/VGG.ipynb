# %%
# %pip install torch torchvision numpy matplotlib opencv-python tqdm
# Out:
# Collecting torch
#   Downloading torch-2.0.0-cp39-cp39-win_amd64.whl (172.3 MB)
#      -------------------------------------- 172.3/172.3 MB 1.9 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.15.1-cp39-cp39-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 2.1 MB/s eta 0:00:00
# Collecting numpy
#   Using cached numpy-1.24.2-cp39-cp39-win_amd64.whl (14.9 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# Collecting opencv-python
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting networkx
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from torch) (4.5.0)
# Collecting filelock
#   Downloading filelock-3.10.0-py3-none-any.whl (9.9 kB)
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 2.1 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 2.0 MB/s eta 0:00:00
# Collecting requests
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0
#   Using cached Pillow-9.4.0-cp39-cp39-win_amd64.whl (2.5 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.2-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.6 MB/s eta 0:00:00
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from matplotlib) (23.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: colorama in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp39-cp39-win_amd64.whl (16 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.9/140.9 kB 1.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muzaf\anaconda3\envs\vgg\lib\site-packages (from requests->torchvision) (2022.12.7)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp39-cp39-win_amd64.whl (97 kB)
#      ---------------------------------------- 97.1/97.1 kB 1.9 MB/s eta 0:00:00
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      -------------------------------------- 536.2/536.2 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: mpmath, urllib3, tqdm, sympy, pyparsing, pillow, numpy, networkx, MarkupSafe, kiwisolver, importlib-resources, idna, fonttools, filelock, cycler, charset-normalizer, requests, opencv-python, jinja2, contourpy, torch, matplotlib, torchvision
# Successfully installed MarkupSafe-2.1.2 charset-normalizer-3.1.0 contourpy-1.0.7 cycler-0.11.0 filelock-3.10.0 fonttools-4.39.2 idna-3.4 importlib-resources-5.12.0 jinja2-3.1.2 kiwisolver-1.4.4 matplotlib-3.7.1 mpmath-1.3.0 networkx-3.0 numpy-1.24.2 opencv-python-4.7.0.72 pillow-9.4.0 pyparsing-3.0.9 requests-2.28.2 sympy-1.11.1 torch-2.0.0 torchvision-0.15.1 tqdm-4.65.0 urllib3-1.26.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn 
import torch.nn.functional as F
import torchvision as tv


import numpy as np
import matplotlib.pyplot as plt
import cv2 
import os

from tqdm import tqdm

# %%
class VGG16(nn.Module):
    def __init__(self):
        super().__init__()

        self.act = nn.ReLu(inplace=True)
        self.maxpool = nn.MaxPool2d(2,2)

        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)

        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)

        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1)

        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        self.flat = nn.Flatten()
        
        self.fc1 = nn.Linear(7*7*512, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, out_nc)

    def forward(self,x):
        out = self.conv1_1(x)
        out = self.act(out)
        out = self.conv1_2(out)
        out = self.act(out)

        out = self.maxpool(out)

        out = self.conv2_1(x)
        out = self.act(out)
        out = self.conv2_2(out)
        out = self.act(out)

        out = self.maxpool(out)

        out = self.conv3_1(x)
        out = self.act(out)
        out = self.conv3_2(out)
        out = self.act(out)
        out = self.conv3_3(out)
        out = self.act(out)

        out = self.maxpool(out)

        out = self.conv4_1(x)
        out = self.act(out)
        out = self.conv4_2(out)
        out = self.act(out)
        out = self.conv4_3(out)
        out = self.act(out)

        out = self.maxpool(out)

        out = self.conv5_1(x)
        out = self.act(out)
        out = self.conv5_2(out)
        out = self.act(out)
        out = self.conv5_3(out)
        out = self.act(out)

        out = self.maxpool(out)
        out = self.flat(out)

        out = self.fc1(out)
        out = self.act(out)
        out = self.fc2(out)
        out = self.act(out)
        out = self.fc3(out)

        return out
